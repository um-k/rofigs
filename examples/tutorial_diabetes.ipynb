# %% [markdown]
# ### Example: diabetes
#
# This tutorial shows how to train `rofigs` models on the diabetes dataset from the paper and demonstrates different functionalities.
#
# First, you need to install the required dependencies with `pip install -r requirements.txt`.

# %%
# %load_ext autoreload        
# %autoreload 2

# %%
import os
import sys                                                    
sys.path.insert(0, os.path.abspath('..'))           

from src.utils import load_final_data, load_data
from src.rofigs import ROFIGSClassifier
from sklearn.metrics import balanced_accuracy_score

# %%
# Load the data
(X_train, y_train), (X_test, y_test) = load_final_data(dataset="diabetes", fold=6)

# %% [markdown]
# Fit and evaluate RO-FIGS models

# %%
model_8 = ROFIGSClassifier(beam_size=8, max_splits=10, min_impurity_decrease=10, random_state=12345)
model_8.fit(X_train, y_train)
# Out:
# ROFIGSClassifier(beam_size=8, max_splits=10, min_impurity_decrease=10,
#                  random_state=12345)

# %%
# set verbose=True to see details of the model training

model_4 = ROFIGSClassifier(beam_size=4, max_splits=10, min_impurity_decrease=10, verbose=True, random_state=12345)
model_4.fit(X_train, y_train)
# Out:
# ********************************************************************************
# ...............................  Iteration = 1  ................................
# ********************************************************************************
# #samples: split = 691, left = 496, right = 195
# values: split = 0.349, left = 0.258, right = 0.579
# impurity reduction: 14.461
#
# ********************************************************************************
# ...............................  Iteration = 2  ................................
# ********************************************************************************
# Adding a new node with impurity reduction of 14.461:
# 	3.973 * X_5 + 3.346 * X_6 <= 3.030 (Tree #-1 root)
#
# >>>>> Splitting on features: 5, 1, 2, 4 <<<<<
#
# There are 3 potential splits:
#
#  **************************************************
# #samples: split = 691, left = 566, right = 125
# values: split = -0.000, left = -0.031, right = 0.140
# impurity reduction: 3.001
#
#  **************************************************
# #samples: split = 496, left = 220, right = 276
# values: split = 0.258, left = 0.132, right = 0.359
# impurity reduction: 6.301
#
#  **************************************************
# #samples: split = 195, left = 97, right = 98
# values: split = 0.579, left = 0.794, right = 0.367
# impurity reduction: 8.866
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 3 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 2.764 * X_2 + 2.768 * X_4 + 1.311 * X_5 <= 3.013 (Tree #-1 root) (imp. red. of 3.001)
# 	 Val: 0.258 (leaf) (imp. red. of 6.301)
# 	 Val: 0.579 (leaf) (imp. red. of 8.866)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 4
#
# >>>>> Splitting on features: 6, 1, 2, 0 <<<<<
#
# There are 3 potential splits:
#
#  **************************************************
# #samples: split = 691, left = 477, right = 214
# values: split = -0.000, left = -0.117, right = 0.261
# impurity reduction: 21.085
#
#  **************************************************
# #samples: split = 496, left = 406, right = 90
# values: split = 0.258, left = 0.165, right = 0.678
# impurity reduction: 19.369
#
#  **************************************************
# #samples: split = 195, left = 79, right = 116
# values: split = 0.579, left = 0.342, right = 0.741
# impurity reduction: 7.504
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 3 potential split(s), 2 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 7.504)
# 	 Val: 0.258 (leaf) (imp. red. of 19.369)
# 	 6.236 * X_1 <= 4.181 (Tree #-1 root) (imp. red. of 21.085)
#
# ********************************************************************************
# ...............................  Iteration = 3  ................................
# ********************************************************************************
# Adding a new node with impurity reduction of 21.085:
# 	6.236 * X_1 <= 4.181 (Tree #-1 root)
#
# >>>>> Splitting on features: 6, 2, 4, 1 <<<<<
#
# There are 5 potential splits:
#
#  **************************************************
# #samples: split = 195, left = 115, right = 80
# values: split = 0.528, left = 0.621, right = 0.395
# impurity reduction: 2.405
#
#  **************************************************
# #samples: split = 496, left = 49, right = 447
# values: split = 0.278, left = 0.571, right = 0.246
# impurity reduction: 4.670
#
#  **************************************************
# #samples: split = 691, left = 278, right = 413
# values: split = -0.000, left = 0.108, right = -0.072
# impurity reduction: 5.388
#
#  **************************************************
# #samples: split = 477, left = 190, right = 287
# values: split = -0.117, left = 0.009, right = -0.201
# impurity reduction: 5.032
#
#  **************************************************
# #samples: split = 214, left = 64, right = 150
# values: split = 0.261, left = 0.496, right = 0.161
# impurity reduction: 5.044
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 5 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 2.405)
# 	 Val: 0.258 (leaf) (imp. red. of 4.67)
# 	 Val: -0.117 (leaf) (imp. red. of 5.032)
# 	 Val: 0.261 (leaf) (imp. red. of 5.044)
# 	 - 2.803 * X_1 + 2.725 * X_4 + 1.210 * X_6 <= -1.343 (Tree #-1 root) (imp. red. of 5.388)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 4
#
# >>>>> Splitting on features: 2, 7, 5, 0 <<<<<
#
# There are 5 potential splits:
#
#  **************************************************
# #samples: split = 195, left = 76, right = 119
# values: split = 0.528, left = 0.382, right = 0.621
# impurity reduction: 2.634
#
#  **************************************************
# #samples: split = 496, left = 181, right = 315
# values: split = 0.278, left = 0.137, right = 0.359
# impurity reduction: 5.662
#
#  **************************************************
# #samples: split = 477, left = 277, right = 200
# values: split = -0.117, left = -0.214, right = 0.017
# impurity reduction: 6.162
#
#  **************************************************
# #samples: split = 214, left = 14, right = 200
# values: split = 0.261, left = -0.187, right = 0.292
# impurity reduction: 2.999
#
#  **************************************************
# #samples: split = 691, left = 177, right = 514
# values: split = -0.000, left = -0.137, right = 0.047
# impurity reduction: 4.438
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 5 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 2.634)
# 	 Val: 0.261 (leaf) (imp. red. of 2.999)
# 	 4.217 * X_5 + 2.270 * X_7 <= 2.263 (Tree #-1 root) (imp. red. of 4.438)
# 	 Val: 0.258 (leaf) (imp. red. of 5.662)
# 	 Val: -0.117 (leaf) (imp. red. of 6.162)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 3
#
# >>>>> Splitting on features: 6, 4, 7, 1 <<<<<
#
# There are 5 potential splits:
#
#  **************************************************
# #samples: split = 195, left = 193, right = 2
# values: split = 0.528, left = 0.536, right = -0.261
# impurity reduction: 1.257
#
#  **************************************************
# #samples: split = 214, left = 71, right = 143
# values: split = 0.261, left = 0.473, right = 0.155
# impurity reduction: 4.799
#
#  **************************************************
# #samples: split = 691, left = 355, right = 336
# values: split = -0.000, left = -0.098, right = 0.104
# impurity reduction: 7.028
#
#  **************************************************
# #samples: split = 496, left = 277, right = 219
# values: split = 0.278, left = 0.188, right = 0.393
# impurity reduction: 5.138
#
#  **************************************************
# #samples: split = 477, left = 277, right = 200
# values: split = -0.117, left = -0.214, right = 0.017
# impurity reduction: 6.162
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 5 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 1.257)
# 	 Val: 0.261 (leaf) (imp. red. of 4.799)
# 	 Val: 0.258 (leaf) (imp. red. of 5.138)
# 	 Val: -0.117 (leaf) (imp. red. of 6.162)
# 	 5.089 * X_7 <= 0.719 (Tree #-1 root) (imp. red. of 7.028)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 2
#
# >>>>> Splitting on features: 2, 1, 5, 0 <<<<<
#
# There are 5 potential splits:
#
#  **************************************************
# #samples = 195 --> no split was created, return leaf
#
#  **************************************************
# #samples: split = 214, left = 122, right = 92
# values: split = 0.261, left = 0.140, right = 0.421
# impurity reduction: 4.157
#
#  **************************************************
# #samples: split = 496, left = 235, right = 261
# values: split = 0.278, left = 0.178, right = 0.369
# impurity reduction: 4.496
#
#  **************************************************
# #samples: split = 477, left = 289, right = 188
# values: split = -0.117, left = -0.201, right = 0.012
# impurity reduction: 5.124
#
#  **************************************************
# #samples: split = 691, left = 217, right = 474
# values: split = -0.000, left = -0.090, right = 0.041
# impurity reduction: 2.572
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 5 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 0)
# 	 2.694 * X_1 + 4.324 * X_5 <= 3.577 (Tree #-1 root) (imp. red. of 2.572)
# 	 Val: 0.261 (leaf) (imp. red. of 4.157)
# 	 Val: 0.258 (leaf) (imp. red. of 4.496)
# 	 Val: -0.117 (leaf) (imp. red. of 5.124)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 1
#
# >>>>> Splitting on features: 3, 6, 2, 5 <<<<<
#
# There are 5 potential splits:
#
#  **************************************************
# #samples = 195 --> no split was created, return leaf
#
#  **************************************************
# #samples: split = 691, left = 382, right = 309
# values: split = -0.000, left = 0.035, right = -0.043
# impurity reduction: 1.029
#
#  **************************************************
# #samples: split = 214, left = 159, right = 55
# values: split = 0.261, left = 0.321, right = 0.085
# impurity reduction: 2.276
#
#  **************************************************
# #samples: split = 496, left = 176, right = 320
# values: split = 0.278, left = 0.150, right = 0.349
# impurity reduction: 4.505
#
#  **************************************************
# #samples = 477 --> no split was created, return leaf
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# Out of 5 potential split(s), 0 has/have sufficient impurity reduction (i.e., > 10):
# 	 Val: 0.579 (leaf) (imp. red. of 0)
# 	 Val: -0.117 (leaf) (imp. red. of 0)
# 	 0.606 * X_3 + 5.937 * X_6 <= 1.091 (Tree #-1 root) (imp. red. of 1.029)
# 	 Val: 0.261 (leaf) (imp. red. of 2.276)
# 	 Val: 0.258 (leaf) (imp. red. of 4.505)
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
# >> Number of repetitions left: 0
#
# ********************************************************************************
# ...............................  Iteration = 4  ................................
# ********************************************************************************
#
#
# --Annotation--
#
# >>>>> 3.973 * X_5 + 3.346 * X_6 <= 3.030 (Tree #0 root) <<<<<
# #samples = 691; L: 496, R: 195
#
# >>>>> Val: 0.258 (leaf) <<<<<
# #samples = 496
#
# >>>>> Val: 0.579 (leaf) <<<<<
# #samples = 195
#
# >>>>> 6.236 * X_1 <= 4.181 (Tree #1 root) <<<<<
# #samples = 691; L: 477, R: 214
#
# >>>>> Val: -0.117 (leaf) <<<<<
# #samples = 477
#
# >>>>> Val: 0.261 (leaf) <<<<<
# #samples = 214
# ROFIGSClassifier(beam_size=4, max_splits=10, min_impurity_decrease=10,
#                  random_state=12345, verbose=True)

# %%
# Evaluate models
acc_4 = 100 * balanced_accuracy_score(y_test, model_4.predict(X_test))
print(f"Model with beam_size=4 has \n\t{model_4.count_trees()} trees, {model_4.count_splits()} splits, and {model_4.get_average_num_feat_per_split():.1f} features per split \n\tbalanced accuracy of {acc_4:.1f}\n")

acc_8 = 100 * balanced_accuracy_score(y_test, model_8.predict(X_test))
print(f"Model with beam_size=8 has \n\t{model_8.count_trees()} trees, {model_8.count_splits()} splits, and {model_8.get_average_num_feat_per_split():.1f} features per split \n\tbalanced accuracy of {acc_8:.1f}")
# Out:
# Model with beam_size=4 has
# 	2 trees, 2 splits, and 1.5 features per split
# 	balanced accuracy of 65.1
#
# Model with beam_size=8 has
# 	1 trees, 1 splits, and 3.0 features per split
# 	balanced accuracy of 72.5

# %% [markdown]
# Access feature combinations that appear in splits

# %%
# model_4 has two splits: one with two features and one with one feature
print(f"Feature combinations in model_4: {model_4.feature_combinations}") 

# model_8 has only one split with three features
print(f"Feature combinations in model_8: {model_8.feature_combinations}")
# Out:
# Feature combinations in model_4: [(5, 6), (1,)]
# Feature combinations in model_8: [(1, 5, 7)]
